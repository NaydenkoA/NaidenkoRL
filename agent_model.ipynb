# %%
import numpy as np
import pandas as pd

# %%
from utils import plot

nect_df = pd.read_csv('datas/nect_honey_price.csv')
island_df = pd.read_csv('datas/island_data.csv')

nect_price = nect_df['price'].values
nav = island_df['nav'].values
volatile_part = island_df['wbtc_frac'].values

timestamp = nect_df['timestamp'].values

SCALE = 6.5*10**7
nav = nav/SCALE

# %%
plot(
    timestamp,
    nect_price,
    'timestamp',
    'price',
    'NECT price'
)

plot(
    timestamp,
    nav,
    'timestamp',
    'price',
    'NAV'
)

plot(
    timestamp,
    volatile_part*100,
    'timestamp',
    '%',
    'Volatile part in LP'
)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from special_functions import plateau, deltaFunctionBarier
import random

class agentDLVEnv(gym.Env):
    def __init__(
            self,
            nect_honey_price,
            LP_nav_honey,
            volatile_part,
            init_LP = 1,
            max_step = 0.15,
            target_leverage = 2,
            min_cr = 1.2,
            is_training = False,
            spread = 0.005,
            impact_coeff = 0.0005,
            primordial_action_penalty = 0.015,
            penalty_damping = 0.1
        ):
        
        super(agentDLVEnv, self).__init__()

        self.nect_price = nect_honey_price
        self.nav = LP_nav_honey/nect_honey_price # nav in terms of nect
        self.volatile_part = volatile_part # % of the volatile token (wbtc) in the LP token
        self.num_of_liquidations = 0
        self.max_steps = len(self.nav)
        self.target_leverage = target_leverage
        self.starting_LP = init_LP
        self.max_action = max_step
        self.min_cr = min_cr
        self.is_training = is_training
        self.spread = spread
        self.impact_coeff = impact_coeff
        self.primordial_action_penalty = primordial_action_penalty
        self.action_penalty_damping = penalty_damping 

        self.action_space = spaces.Box(low=0, high=1, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(12,), dtype=np.float32)

        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.step_count = 0
        self.LP = self.starting_LP
        self.collateral_value = self.LP*self.nav[0]
        self.volatile_part_value = self.collateral_value*self.volatile_part[0]
        if self.is_training:
            self.nect = (self.collateral_value - self.volatile_part_value)*(self.target_leverage - 1)
            self.nect = random.uniform(0.1, 3*self.nect)
        else:
            self.nect = (self.collateral_value - self.volatile_part_value)*(self.target_leverage - 1)
        self.leverage_margin = self.nect/(self.collateral_value - self.volatile_part_value) + 1 - self.target_leverage
        self.cr_margin = self.collateral_value/self.nect - self.min_cr
        self.LP_margin = self.LP/self.starting_LP

        self.nect_gain_margin = 0
        self.lp_gain_margin = 0
        self.collateral_value_gain_margin = 0
        self.volatile_part_value_gain_margin = 0
        self.leverage_gain_margin = 0
        self.cr_margin_gain_margin = 0
        self.prev_action_cost = 0
        self.current_action_penalty = 0 

        self.history = {
            'NECT': [],
            'collateral value': [],
            'volatile value': [],
            'reward': [],
            'leverage': [],
            'collaterization ratio': [],
            'LP': []
        }

        obs = self._get_obs()
        info = {}
        return obs, info

    def _get_obs(self):
        return np.array([
            self.nect,
            self.collateral_value,
            self.volatile_part_value,
            self.leverage_margin,
            self.cr_margin,
            self.LP_margin,
            self.nect_gain_margin,
            self.lp_gain_margin,
            self.collateral_value_gain_margin,
            self.volatile_part_value_gain_margin,
            self.leverage_gain_margin,
            self.cr_margin_gain_margin
        ], dtype=np.float32)
    
    def _compute_transaction_cost(self, action_size):
        return abs(action_size)*self.spread + self.impact_coeff * (action_size ** 2)

    def step(self, action):

        if action[0]>action[1]:
            action_size = 0
            action_penalty = 0
            self.current_action_penalty = self.current_action_penalty*self.action_penalty_damping
        else:
            nect_target = (self.target_leverage - 1)*(self.collateral_value - self.volatile_part_value)
            action_size = nect_target - self.nect
            self.current_action_penalty = self.primordial_action_penalty + self.current_action_penalty*self.action_penalty_damping
            action_penalty = self.current_action_penalty
        
        cost = self._compute_transaction_cost(action_size)
        self.prev_action_cost = cost
        
        current_nav = self.nav[self.step_count]
        nect_price = self.nect_price[self.step_count]

        nect = max(self.nect + action_size, 0)
        self.nect_gain_margin = min(nect/(self.nect + 1e-10) - 1, 10)
        self.nect = nect

        lp = self.LP - cost/current_nav
        self.lp_gain_margin = lp/(self.LP + 1e-10) - 1
        self.LP = lp

        if lp <= 0:
            self.num_of_liquidations += 1
            liquidation_penalty = deltaFunctionBarier(0)
            if self.is_training:
                self.LP = self.starting_LP
                terminated = False
                truncated = self.step_count >= self.max_steps - 1
            else:
                terminated = True
                truncated = True
        else:
            liquidation_penalty = 0

        action_penalty = 1/2*(action_penalty + 20*cost/current_nav)
        self.LP_margin = self.LP/self.starting_LP

        collateral_value = current_nav*self.LP
        self.collateral_value_gain_margin = collateral_value/(self.collateral_value + 1e-10) - 1
        self.collateral_value = collateral_value

        volatile_part_value = self.volatile_part[self.step_count]*self.collateral_value
        self.volatile_part_value_gain_margin = volatile_part_value/(self.volatile_part_value + 1e-10) - 1
        self.volatile_part_value = volatile_part_value

        leverage = self.nect/(self.collateral_value - self.volatile_part_value + 1e-10) + 1 
        self.leverage_gain_margin = leverage/(self.leverage_margin + self.target_leverage + 1e-10) - 1
        self.leverage_margin = leverage - self.target_leverage

        cr_margin = self.collateral_value/(self.nect + 1e-8) - self.min_cr
        self.cr_margin_gain_margin = cr_margin/self.cr_margin - 1
        self.cr_margin = cr_margin
        if self.cr_margin <= 0:
            self.num_of_liquidations += 1
            liquidation_penalty = liquidation_penalty + deltaFunctionBarier(0)
            if self.is_training:
                terminated = False
                truncated = self.step_count >= self.max_steps - 1
            else:
                terminated = True
                truncated = True
        else:
            liquidation_penalty = liquidation_penalty + deltaFunctionBarier(self.cr_margin)
            terminated = False
            truncated = self.step_count >= self.max_steps - 1

        leverage_reward = plateau(self.leverage_margin)
        reward = leverage_reward - liquidation_penalty - action_penalty

        self.history['NECT'].append(self.nect)
        self.history['collateral value'].append(self.collateral_value*nect_price)
        self.history['volatile value'].append(self.volatile_part_value*nect_price)
        self.history['leverage'].append(self.target_leverage + self.leverage_margin)
        self.history['reward'].append(reward)
        self.history['collaterization ratio'].append(self.cr_margin + self.min_cr)
        self.history['LP'].append(self.LP)

        obs = self._get_obs()
        self.step_count += 1
        info = {}

        return obs, reward, terminated, truncated, info
    
    def get_history(self):
        return self.history, self.num_of_liquidations

# %%
from utils import plot_training_metrics
#from raw_env import rawDLVEnv

env = agentDLVEnv(nect_honey_price=nect_price, LP_nav_honey=nav, volatile_part=volatile_part)

done = False
while not done:
    action = env.action_space.sample()  # Random action
    obs, reward, _, done, _ = env.step(action)

plot_training_metrics(env.history)

# %%
def naiveAgent(obs, target_leverage = 2, max_step = 0.15):

    nect = obs[0]
    leverage = obs[3]+2
    colateral_value = obs[1]
    volatile_part_value = obs[2]

    if abs(leverage - target_leverage)/target_leverage<=0.01:
        return [1,0]
    else:
        return [0,1]
    
env = agentDLVEnv(nect_honey_price=nect_price, LP_nav_honey=nav, volatile_part=volatile_part)

obs, _ = env.reset()

done = False
while not done:
    action = naiveAgent(obs)  
    obs, reward, _, done, _ = env.step(action)

agent_history = env.history
plot_training_metrics(agent_history)

# %%
from stable_baselines3 import PPO
import random
import torch
from stable_baselines3.common.utils import get_linear_fn

SEED = 400
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

train_env = agentDLVEnv(
    nect_honey_price=nect_price, 
    LP_nav_honey=nav, 
    volatile_part=volatile_part,
    is_training=True
)

model = PPO(
    "MlpPolicy", 
    train_env, 
    verbose=1
)
model.learn(total_timesteps=300000)
#model.save("ppo_leverage_historical")

_, num_of_liquidation = train_env.get_history()
print('Liquidations during learnings:', num_of_liquidation)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2880 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1874         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044596535 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.000666    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.75         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 1.02         |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006040966 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 1.01        |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1636         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0041868887 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.00284     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 1            |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.95e+03    |
# | time/                   |             |
# |    fps                  | 1601        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005904526 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.00285     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.99        |
# |    value_loss           | 86.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.95e+03     |
# | time/                   |              |
# |    fps                  | 1575         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0031675724 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.00163      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000466    |
# |    std                  | 0.985        |
# |    value_loss           | 73.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.95e+03     |
# | time/                   |              |
# |    fps                  | 1560         |
# |    iterations           | 7            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0094358735 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | -0.000103    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.71         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 0.97         |
# |    value_loss           | 52.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.95e+03    |
# | time/                   |             |
# |    fps                  | 1547        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006042418 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.00082     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.964       |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.95e+03     |
# | time/                   |              |
# |    fps                  | 1537         |
# |    iterations           | 9            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0020576261 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | -0.000448    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00134     |
# |    std                  | 0.939        |
# |    value_loss           | 27.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1531        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009946365 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.00303     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.339       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.933       |
# |    value_loss           | 18.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.9e+03      |
# | time/                   |              |
# |    fps                  | 1522         |
# |    iterations           | 11           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0059986464 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | -7.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.944        |
# |    value_loss           | 12.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1522        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015123508 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | -5.4e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0471      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.952       |
# |    value_loss           | 7.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013003934 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.000433    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0245      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00307     |
# |    std                  | 0.945       |
# |    value_loss           | 4.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 14          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011762392 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | -0.000108   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.932       |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.92e+03    |
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 15          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016897976 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.00253     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.917       |
# |    value_loss           | 1.46        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 9.92e+03   |
# | time/                   |            |
# |    fps                  | 1525       |
# |    iterations           | 16         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01069687 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | 0.000267   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0179    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00245   |
# |    std                  | 0.918      |
# |    value_loss           | 39.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.92e+03    |
# | time/                   |             |
# |    fps                  | 1526        |
# |    iterations           | 17          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010438729 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.00694     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00616     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00714    |
# |    std                  | 0.895       |
# |    value_loss           | 0.469       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.92e+03    |
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008301858 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | -0.0119     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 0.878       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.92e+03    |
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 19          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006480042 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | -0.022      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00359    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00066     |
# |    std                  | 0.879       |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.88e+03    |
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 20          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008699097 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00623     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.863       |
# |    value_loss           | 0.0942      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.88e+03     |
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 21           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0067995563 |
# |    clip_fraction        | 0.0871       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | -0.000758    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00884      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000864    |
# |    std                  | 0.858        |
# |    value_loss           | 0.056        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.88e+03    |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 22          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009869543 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.00204     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.834       |
# |    value_loss           | 0.0322      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.88e+03    |
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 23          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009058387 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | -0.00626    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00977    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00629    |
# |    std                  | 0.825       |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.88e+03    |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 24          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004745074 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.0327      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000213   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000318   |
# |    std                  | 0.824       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 25          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010431474 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00515    |
# |    std                  | 0.812       |
# |    value_loss           | 0.00824     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 26          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006793669 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 234         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00449    |
# |    std                  | 0.803       |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 27          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006474047 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.0336      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.782       |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.9e+03      |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 28           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0059817014 |
# |    clip_fraction        | 0.0803       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.018        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.783        |
# |    value_loss           | 0.00211      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.9e+03     |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 29          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007357395 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | -0.0673     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000926   |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.796       |
# |    value_loss           | 0.00617     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.85e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 30           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0046791574 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00892      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.8          |
# |    value_loss           | 0.00152      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.85e+03     |
# | time/                   |              |
# |    fps                  | 1516         |
# |    iterations           | 31           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020984786 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | -3.02e+04    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000267     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000979    |
# |    std                  | 0.782        |
# |    value_loss           | 6.72         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.85e+03    |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 32          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004830874 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | -0.00567    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0043     |
# |    std                  | 0.77        |
# |    value_loss           | 0.000479    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.85e+03     |
# | time/                   |              |
# |    fps                  | 1516         |
# |    iterations           | 33           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0037494274 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.00124      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00346      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00266     |
# |    std                  | 0.785        |
# |    value_loss           | 0.00175      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.85e+03    |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 34          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004208237 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | -0.0322     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00129    |
# |    std                  | 0.795       |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.87e+03     |
# | time/                   |              |
# |    fps                  | 1518         |
# |    iterations           | 35           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0038405047 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0252      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00217     |
# |    std                  | 0.814        |
# |    value_loss           | 0.00811      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.87e+03     |
# | time/                   |              |
# |    fps                  | 1518         |
# |    iterations           | 36           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0013683693 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.0174       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000387    |
# |    std                  | 0.814        |
# |    value_loss           | 3.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.87e+03     |
# | time/                   |              |
# |    fps                  | 1519         |
# |    iterations           | 37           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0050607934 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.061        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.054        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000975    |
# |    std                  | 0.812        |
# |    value_loss           | 0.0321       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.87e+03    |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 38          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004253841 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.808       |
# |    value_loss           | 0.813       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.87e+03     |
# | time/                   |              |
# |    fps                  | 1519         |
# |    iterations           | 39           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0070145503 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.176        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.809        |
# |    value_loss           | 0.362        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.56e+03     |
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 40           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0002129295 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000213     |
# |    std                  | 0.804        |
# |    value_loss           | 2.86         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.56e+03     |
# | time/                   |              |
# |    fps                  | 1519         |
# |    iterations           | 41           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0031316583 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00928     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000238    |
# |    std                  | 0.795        |
# |    value_loss           | 33.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.56e+03    |
# | time/                   |             |
# |    fps                  | 1520        |
# |    iterations           | 42          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004530256 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000141   |
# |    std                  | 0.78        |
# |    value_loss           | 0.00684     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.56e+03     |
# | time/                   |              |
# |    fps                  | 1521         |
# |    iterations           | 43           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0029468115 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0271       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.783        |
# |    value_loss           | 0.0711       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.58e+03    |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 44          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005483618 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0059      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.789       |
# |    value_loss           | 0.0204      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.58e+03     |
# | time/                   |              |
# |    fps                  | 1521         |
# |    iterations           | 45           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0076241232 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0576       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0063      |
# |    std                  | 0.778        |
# |    value_loss           | 0.179        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.58e+03     |
# | time/                   |              |
# |    fps                  | 1522         |
# |    iterations           | 46           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0038879523 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00815     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000317     |
# |    std                  | 0.77         |
# |    value_loss           | 0.000365     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.58e+03    |
# | time/                   |             |
# |    fps                  | 1522        |
# |    iterations           | 47          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005204265 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00645    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000241   |
# |    std                  | 0.764       |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.58e+03     |
# | time/                   |              |
# |    fps                  | 1523         |
# |    iterations           | 48           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063871546 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.018        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.75         |
# |    value_loss           | 0.00448      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.62e+03    |
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 49          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.003924382 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000258    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.754       |
# |    value_loss           | 0.00609     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 9.62e+03   |
# | time/                   |            |
# |    fps                  | 1522       |
# |    iterations           | 50         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00705418 |
# |    clip_fraction        | 0.0668     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.27      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00783   |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00188   |
# |    std                  | 0.75       |
# |    value_loss           | 0.0197     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.62e+03     |
# | time/                   |              |
# |    fps                  | 1523         |
# |    iterations           | 51           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0038315486 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.855        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00729     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00191     |
# |    std                  | 0.741        |
# |    value_loss           | 0.000149     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.62e+03    |
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 52          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.003348383 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00567     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00134    |
# |    std                  | 0.734       |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.62e+03     |
# | time/                   |              |
# |    fps                  | 1523         |
# |    iterations           | 53           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0051853536 |
# |    clip_fraction        | 0.0365       |
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.74e+03     |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 131          |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0054879305 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | -0.253       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0053       |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.832        |
# |    value_loss           | 0.00405      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 132          |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0035646982 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | -0.262       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0139       |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00335     |
# |    std                  | 0.848        |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.75e+03    |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 133         |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.004010985 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | -386        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00332     |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00141    |
# |    std                  | 0.848       |
# |    value_loss           | 0.477       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.75e+03    |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 134         |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.008552052 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.833       |
# |    value_loss           | 4.13e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 135          |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0036816702 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00843      |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00211     |
# |    std                  | 0.821        |
# |    value_loss           | 0.000111     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 9.75e+03   |
# | time/                   |            |
# |    fps                  | 1514       |
# |    iterations           | 136        |
# |    time_elapsed         | 183        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.00391488 |
# |    clip_fraction        | 0.0382     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | -0.203     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0411     |
# |    n_updates            | 1350       |
# |    policy_gradient_loss | -0.00162   |
# |    std                  | 0.832      |
# |    value_loss           | 0.0133     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1514         |
# |    iterations           | 137          |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0023350017 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00699      |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.842        |
# |    value_loss           | 0.00124      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 138          |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0051130243 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.0209       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0126       |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00043     |
# |    std                  | 0.85         |
# |    value_loss           | 1.46         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.75e+03    |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 139         |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.006072592 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00423    |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00707    |
# |    std                  | 0.826       |
# |    value_loss           | 5.35e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 140          |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0055101207 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0252      |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00419     |
# |    std                  | 0.833        |
# |    value_loss           | 0.000581     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.75e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 141          |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0051767873 |
# |    clip_fraction        | 0.0667       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | -0.176       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0222      |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00482     |
# |    std                  | 0.839        |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.76e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 142          |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0083356425 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00548      |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00564     |
# |    std                  | 0.853        |
# |    value_loss           | 0.00472      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.76e+03    |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 143         |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.008029612 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | -58.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00919    |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00362    |
# |    std                  | 0.869       |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 9.76e+03    |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 144         |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008897468 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00215     |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00905    |
# |    std                  | 0.851       |
# |    value_loss           | 2.91e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.76e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 145          |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0034200307 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | -0.272       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00166     |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.851        |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.76e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 146          |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0046620104 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.0557       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0017      |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.867        |
# |    value_loss           | 0.00681      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 9.77e+03     |
# | time/                   |              |
# |    fps                  | 1515         |
# |    iterations           | 147          |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0036528232 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.705        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00265     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 0.873        |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# Liquidations during learnings: 66

# %%
eval_env = agentDLVEnv(
    nect_honey_price=nect_price, 
    LP_nav_honey=nav, 
    volatile_part=volatile_part
)

obs, _ = eval_env.reset()
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, _, done, _ = eval_env.step(action)

history, _ = eval_env.get_history()
plot_training_metrics(history)

# %%
from utils import plot_training_comparison

plot_training_comparison(agent_history, [history])
